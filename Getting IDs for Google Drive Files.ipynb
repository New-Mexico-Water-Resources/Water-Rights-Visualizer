# %%
from dateutil import parser
import pandas as pd
import raster as rt
from water_rights_visualizer.google_drive import google_drive_login

# %%
drive = google_drive_login()
drive
# Out:
# loading credentials: /Users/gregory/Projects/Water-Rights-Visualizer/water_rights_visualizer/google_drive_key.txt
# [2023-03-01 21:13:54 INFO] access_token is expired. Now: 2023-03-02 05:13:54.603888, token_expiry: 2023-03-02 05:06:48
# [2023-03-01 21:13:54 INFO] Refreshing access_token
# saving credentials: /Users/gregory/Projects/Water-Rights-Visualizer/water_rights_visualizer/google_drive_key.txt

# %%
landsat_directory_ID = "1HlxDjX2T-KPEG5UQyB8uHO_GFU-3sASi"
date_directory_listing = drive.ListFile({'q': f"'{landsat_directory_ID}' in parents and trashed=false"}).GetList()

date_directory_ID_rows = []

for date_directory_item in date_directory_listing:
    datestamp = str(date_directory_item["title"])
    try:
        d = parser.parse(datestamp).date()
    except Exception as e:
        continue

    date_directory_ID = str(date_directory_item["id"])
    print(d, date_directory_ID)
    date_directory_ID_rows.append([d, date_directory_ID])
    
date_directory_IDs = pd.DataFrame(date_directory_ID_rows, columns=["date", "ID"])
date_directory_IDs
# Out:
#             date                                 ID
# 0     2020-05-01  1Bok205YpAqARQpQLCPpMsEN_hjOaILW6
# 1     2020-04-30  1juLtZvZpn_MEqX6PXhY51ODtQUyoKhjV
# 2     2020-04-29  1BnYtFJ_iogL_M_-tkcAVB8BZ0WcYbeDs
# 3     2020-04-28  1oLKlLGNzD96YibawvI_X6VeHNtXbc1v6
# 4     2020-04-27  1FEbpzEGymROWbO7Oqc2cLjtUDOxOLzlv
# ...          ...                                ...
# 8050  1982-11-23  1XDaWNuPWHOF_gXiZzYDOA1ctS085_voJ
# 8051  1982-11-25  1NaobbM6CH0te9mnlEljRxJJSFVr8tb0H
# 8052  1982-11-16  1Wq_T2b5V0_K6ZCsAzehNmZ21nXwnxIqu
# 8053  1982-12-04  1iAydZC2x_9gfYBCe7Wqz2RtY48YwcmY3
# 8054  1982-12-13  13wUcs0MQLMglwSTpUnquThn4TJ5e1XvP
#
# [8055 rows x 2 columns]

# %%
granule_directory_ID_rows = []

for i, (d, date_directory_ID) in date_directory_IDs[:3].iterrows():
    granule_directory_listing = drive.ListFile({'q': f"'{date_directory_ID}' in parents and trashed=false"}).GetList()

    for granule_directory_item in granule_directory_listing:
        granule_ID = str(granule_directory_item["title"])
        granule_directory_ID = str(granule_directory_item["id"])
        print(granule_ID, granule_directory_ID)
        granule_directory_ID_rows.append([d, granule_ID, granule_directory_ID])

granule_directory_IDs = pd.DataFrame(granule_directory_ID_rows, columns=["date", "granule_ID", "granule_directory_ID"])
granule_directory_IDs
# Out:
# LC08_CU_012015_20191227_20200523_C01_V01_ET 1VY8JHz_pWzjxokhbMnowYJqvgG7mmmnn
# LC08_CU_012014_20191227_20200526_C01_V01_ET 1-_9SqZDRrRl_menA2lqu5gm6t0FJ5FfW
# LE07_CU_012011_20200430_20200610_C01_V01_ET 1BMiPOcNPaj0Q5meAZpCTu8z6dnP2CamY
# LE07_CU_010012_20200430_20200606_C01_V01_ET 1FmwYjEi4y5avgMHAe003u2A0uYMsvyxu
# LE07_CU_009014_20200430_20200606_C01_V01_ET 1wpgpQRNDLD8HBkZ8KEXd6KKxUaZehnAj
# LC08_CU_011012_20200429_20200525_C01_V01_ET 1z1M97EO0StBGB4vkDlPSSZYBICEPF0Xx
# LC08_CU_011011_20200429_20200526_C01_V01_ET 11fKsFEwv6VLdqlwnSzGi2nu8UIgJ6DT9
# 7   19PiSObAabdKN1wMakGN0Nv-GuMflo2we
# 8   1x590jgKMn0yM5928hTEbA7pca8Dy5TSx
# 9   1Gc931PBjO6EfxF1ki_a_nQGVz3X6IoEy
# 10  1ZArFktyp6f-qJR0baaRTguFNeJ_d0Bxb
# 11  1edWenh6kCx0L5M2d8_9b5qBd2IrHnKkA
# 12  1aE2Pvkn9KYpXTRitu73gTOjhixcVZ_3u
# 13  1JyAKaeLLhuVzTzwzgbIXy9Fhy2HjA-KH
# 14  1aG3fYlkOUZeVO8MRR7lZJihgE6lAOAhL
# 15  1xnro11IVctFhTAd8VTFvEJtwogULph-1
# 16  1FOglP17bIm01eBBXnqDZFWU-BCpT42A3
# 17  1vxNPAVasKNvhmPnpVA2STENDkPBzWaoW
# 18  1zkG5quAPd8JDkncxUcbXrVZVPB9FhTrN

# %%
file_ID_rows = []

for i, (d, grnaule_ID, granule_directory_ID) in granule_directory_IDs[:3].iterrows():
    file_listing = drive.ListFile({'q': f"'{granule_directory_ID}' in parents and trashed=false"}).GetList()

    for file_item in file_listing:
        filename = str(file_item["title"])
        file_ID = str(file_item["id"])
        print(filename, file_ID)
        file_ID_rows.append([d, granule_ID, filename, file_ID])

file_IDs = pd.DataFrame(file_ID_rows, columns=["date", "granule_ID", "filename", "file_ID"])
file_IDs
# Out:
# LC08_CU_012015_20191227_20200523_C01_V01_ESI.tif 1CGr0b3LDInbbTgfnszTfeUa5213XwOv4
# LC08_CU_012015_20191227_20200523_C01_V01_ET.tif 17cRNNgLBmbNowqcsPAcWtjWm3nExShkX
# LC08_CU_012014_20191227_20200526_C01_V01_ESI.tif 1cb3fWceu-cpLJW_hSP5Aju-XeqTxXPY9
# LC08_CU_012014_20191227_20200526_C01_V01_ET.tif 1nqjSqxgSkaDInIL7Fg9siGrNI-zOP3QE
# LE07_CU_012011_20200430_20200610_C01_V01_ESI.tif 1Z9caGN8u6yKHAti2AX709auXwFhG5kUH
# LE07_CU_012011_20200430_20200610_C01_V01_ET.tif 1nAyLXnu2I5_DA_11sEFIuZZriv9-s9u0
#          date                                   granule_ID  \
# 0  2020-05-01  LC08_CU_008014_20200429_20200528_C01_V01_ET
# 1  2020-05-01  LC08_CU_008014_20200429_20200528_C01_V01_ET
# 2  2020-05-01  LC08_CU_008014_20200429_20200528_C01_V01_ET
# 3  2020-05-01  LC08_CU_008014_20200429_20200528_C01_V01_ET
# 4  2020-04-30  LC08_CU_008014_20200429_20200528_C01_V01_ET
# 5  2020-04-30  LC08_CU_008014_20200429_20200528_C01_V01_ET
#
#                                            filename  \
# 0  LC08_CU_012015_20191227_20200523_C01_V01_ESI.tif
# 1   LC08_CU_012015_20191227_20200523_C01_V01_ET.tif
# 2  LC08_CU_012014_20191227_20200526_C01_V01_ESI.tif
# 3   LC08_CU_012014_20191227_20200526_C01_V01_ET.tif
# 4  LE07_CU_012011_20200430_20200610_C01_V01_ESI.tif
# 5   LE07_CU_012011_20200430_20200610_C01_V01_ET.tif
#
#                              file_ID
# 0  1CGr0b3LDInbbTgfnszTfeUa5213XwOv4
# 1  17cRNNgLBmbNowqcsPAcWtjWm3nExShkX
# 2  1cb3fWceu-cpLJW_hSP5Aju-XeqTxXPY9
# 3  1nqjSqxgSkaDInIL7Fg9siGrNI-zOP3QE
# 4  1Z9caGN8u6yKHAti2AX709auXwFhG5kUH
# 5  1nAyLXnu2I5_DA_11sEFIuZZriv9-s9u0
